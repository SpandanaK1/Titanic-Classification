# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# reading data set

# %%
Titanicdata=pd.read_csv('Titanic-Dataset.csv')
testdata=pd.read_csv('tested.csv')

# %%
Titanicdata.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Titanicdata.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
Titanicdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x='Survived',data=Titanicdata)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Pclass',data=traindata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b63558b49dc2> in <cell line: 1>()
# ----> 1 sns.countplot(x='Pclass',data=traindata)
#
# NameError: name 'traindata' is not defined

# %%
sexcounts=Titanicdata['Sex'].value_counts()

# %%
plt.pie(sexcounts, labels=sexcounts.index)
plt.show()

# %%
sns.histplot(x='Age',data=Titanicdata)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.countplot(x='Survived',data=testdata)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Pclass',data=testdata)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.histplot(x='Age',data=testdata)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.distplot(traindata['Age'])
# Out:
# <ipython-input-60-a65b15724cff>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(traindata['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
traindata[traindata['Age']<20].groupby(['Sex','Pclass']).mean()
# Out:
# <ipython-input-61-4498d2337a3c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   traindata[traindata['Age']<20].groupby(['Sex','Pclass']).mean()
#                PassengerId  Survived        Age     SibSp     Parch  \
# Sex    Pclass
# female 1        508.500000  0.928571  16.000000  0.571429  0.928571
#        2        404.750000  1.000000  10.875000  0.500000  1.000000
#        3        398.600000  0.533333  10.600000  1.311111  0.866667
# male   1        484.142857  0.571429  12.702857  1.000000  1.428571
#        2        427.789474  0.526316  10.543684  0.473684  0.631579
#        3        454.126984  0.190476  12.705079  1.460317  0.714286
#
#                      Fare
# Sex    Pclass
# female 1       110.684229
#        2        25.181250
#        3        16.948429
# ...

# %%
sns.countplot(x='Pclass',hue='Survived',data=traindata,)
plt.title('survived vs non survived')
plt.show()

# %%
data = [traindata, testdata]
for dataset in data:
    dataset['relatives'] = dataset['SibSp'] + dataset['Parch']
    dataset.loc[dataset['relatives'] > 0, 'not_alone'] = 0
    dataset.loc[dataset['relatives'] == 0, 'not_alone'] = 1
    dataset['not_alone'] = dataset['not_alone'].astype(int)
traindata['not_alone'].value_counts()
# Out:
# 1    537
# 0    354
# Name: not_alone, dtype: int64

# %%
traindata['Fare'].value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64

# %%
traindata_len=len(traindata)
df=pd.concat([traindata,testdata],axis=0)
df=df.reset_index(drop=True)
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  relatives  not_alone
# 0      0         A/5 21171   7.2500   NaN        S          1          0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             354
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1374
# Embarked          4
# relatives         0
# not_alone         0
# dtype: int64

# %%
df=df.drop(columns=['Ticket'],axis=1)

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Embarked']=df['Embarked'].fillna(df['Fare'].mean())

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode())

# %%
sns.displot(df['Fare'])

# %%
df['Fare'] = np.log(df['Fare']+1)

# %%
sns.distplot(df['Fare'])
# Out:
# <ipython-input-75-70b4b4beb1b5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='viridis')
# Out:
# <ipython-input-76-11b57cf04392>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %%
sns.pairplot(traindata)

# %%
df=df.drop(columns=['Name'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
cols=['Sex','Embarked']
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
# 5                                   Moran, Mr. James    1   NaN      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         2
# 1          PC 17599  71.2833   C85         0
# ...

# %%
traindata=df.iloc[:traindata_len, :]
testdata=df.iloc[:traindata_len:, :]

# %%
traindata['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(x='Survived',data=traindata)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
y=traindata['Survived']
y.head(6)
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# Name: Survived, dtype: int64

# %%
df=pd.read_csv("Titanic-Dataset.csv")
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df=pd.read_csv("Titanic-Dataset.csv")
for columns in ['Sex','Embarked']:
    df[columns] = le.fit_transform(df[columns])
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
# 5                                   Moran, Mr. James    1   NaN      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         2
# 1          PC 17599  71.2833   C85         0
# ...

# %%
cols=['Pclass','Sex','Age','SibSp','Parch',"Fare","Embarked"]
x=traindata[cols]
y=traindata['Survived']
print(x.shape)
print(y.shape)
# Out:
# (891, 7)
# (891,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.15,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (757, 7)
# (134, 7)
# (757,)
# (134,)

# %%
def cls_eval(ytest,ypred):
    cm = confusion_matrix(ytest,ypred)
    print('Confusion Matrix\n',cm)
    print('Classification Report\n',classification_report(ytest,ypred))

def mscore(mode):
     print('Training Score',model.score(x_train,y_train))  # Training Accuracy
     print('Testing Score',model.score(x_test,y_test))

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
lr=LogisticRegression(max_iter=1000,solver='liblinear')
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-220841bbb74f> in <cell line: 1>()
# ----> 1 lr=LogisticRegression(max_iter=1000,solver='liblinear')
#       2 lr.fit(x_train,y_train)
#
# NameError: name 'LogisticRegression' is not defined

# %%
mscore(lr)

# %%
ypred_lr = lr.predict(x_test)
print(ypred_lr)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

cls_eval(y_test,ypred_lr)
acc_lr = accuracy_score(y_test,ypred_lr)
print('Accuracy Score',acc_lr)

# %%
knn=KNeighborsClassifier(n_neighbors=8)
knn.fit(x_train,y_train)

# %%
mscore(knn)

# %%
ypred_knn = knn.predict(x_test)
print(ypred_knn)

# %%
cls_eval(y_test,ypred_knn)
acc_knn = accuracy_score(y_test,ypred_knn)
print('Accuracy Score',acc_knn)

# %%
rfc=RandomForestClassifier(n_estimators=80,criterion='entropy',min_samples_split=5,max_depth=10)
rfc.fit(x_train,y_train)

# %%
mscore(rfc)

# %%
ypred_rfc = rfc.predict(x_test)
print(ypred_rfc)

# %%
cls_eval(y_test,ypred_rfc)
acc_rfc = accuracy_score(y_test,ypred_rfc)
print('Accuracy Score',acc_rfc)

# %%
dt = DecisionTreeClassifier(max_depth=5,criterion='entropy',min_samples_split=10)
dt.fit(x_train, y_train)

# %%
mscore(dt)

# %%
ypred_dt = dt.predict(x_test)
print(ypred_dt)

# %%
cls_eval(y_test,ypred_dt)
acc_dt = accuracy_score(y_test,ypred_dt)
print('Accuracy Score',acc_dt)

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_boost  = AdaBoostClassifier(n_estimators=80)
ada_boost.fit(x_train,y_train)

# %%
mscore(ada_boost)

# %%
ypred_ada_boost = ada_boost.predict(x_test)

# %%
cls_eval(y_test,ypred_ada_boost)
acc_adab = accuracy_score(y_test,ypred_ada_boost)
print('Accuracy Score',acc_adab)

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression','knn','Random Forest Classifier','Decision Tree Classifier','Ada Boost Classifier'],
    'Score': [acc_lr,acc_knn,acc_rfc,acc_dt,acc_adab]})

models.sort_values(by = 'Score', ascending = False)

# %%
colors = ["green", "red", "blue", "orange","pink"]

sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
plt.ylabel("Accuracy %")
plt.xlabel("Algorithms")
sns.barplot(x=models['Model'],y=models['Score'], palette=colors )
plt.title('model comparison')
plt.show()
